# %%
import pandas as ps
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = ps.read_csv("test_zipf.csv")
print(df.head())
df.columns = ["item_id", "frequency"]
print(df["frequency"].nunique())
#count rows
row_count = df.shape[0]
print("Number of rows: ", row_count)
# Out:
#    timestamp  item_id
# 0          0        0
# 1          1        0
# 2          2        5
# 3          3       33
# 4          4       17
# 13977
# Number of rows:  1000000

# %%
plt.figure(figsize=(7,5))

plt.rcParams.update({
    "font.size": 10,
    "axes.labelsize": 10,
    "axes.titlesize": 10,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10
})

# %%
#plot histogram of frequency column


sns.histplot(df["frequency"], bins=50, kde=False)
plt.title("Histogram of Frequencies")
plt.xlabel("eventID")
plt.ylabel("Count")
plt.yscale("log")  # logarithmic y-axis
plt.grid(True)

# Save as PNG
plt.savefig("eventID_histogram.png", format="png", dpi=300)  # dpi=300 is good for print
plt.show()
